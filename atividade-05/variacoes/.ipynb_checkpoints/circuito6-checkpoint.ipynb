# %%
from src.circuitos import Circuitos

# %%
Circuitos().circuito_6([]) # ENTRADA: 000
# Out:
# None

# %%
Circuitos().circuito_6([0]) # ENTRADA: 001
# Out:
# None

# %%
Circuitos().circuito_6([1]) # ENTRADA: 010
# Out:
# None

# %%
Circuitos().circuito_6([0,1]) # ENTRADA: 011
# Out:
# None

# %%
Circuitos().circuito_6([0,2]) # ENTRADA: 101
# Out:
# None

# %%
Circuitos().circuito_6([2,1]) # ENTRADA: 110
# Out:
# None

# %%
Circuitos().circuito_6([0,1,2]) # ENTRADA: 111
# Out:
# None
