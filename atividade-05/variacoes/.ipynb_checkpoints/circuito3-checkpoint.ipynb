# %%
from src.circuitos import Circuitos

# %%
Circuitos().circuito_3([]) # ENTRADA: 00
# Out:
# None

# %%
Circuitos().circuito_3([0]) # ENTRADA: 01
# Out:
# None

# %%
Circuitos().circuito_3([1]) # ENTRADA: 10
# Out:
# None

# %%
Circuitos().circuito_3([1,0]) # ENTRADA: 11
# Out:
# None
