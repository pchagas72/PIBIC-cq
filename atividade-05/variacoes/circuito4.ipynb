# %%
from src.circuitos import Circuitos

# %%
Circuitos().circuito_4([]) # ENTRADA: 000
# Out:
# None

# %%
Circuitos().circuito_4([0]) # ENTRADA: 001
# Out:
# None

# %%
Circuitos().circuito_4([1]) # ENTRADA: 010
# Out:
# None

# %%
Circuitos().circuito_4([0,1]) # ENTRADA: 011
# Out:
# None

# %%
Circuitos().circuito_4([0,2]) # ENTRADA: 101
# Out:
# None

# %%
Circuitos().circuito_4([2,1]) # ENTRADA: 110
# Out:
# None

# %%
Circuitos().circuito_4([0,1,2]) # ENTRADA: 111
# Out:
# None
