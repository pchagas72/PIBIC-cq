# %%
from src.circuitos import Circuitos

# %%
Circuitos().circuito_1([]) # ENTRADA: 00
# Out:
# None

# %%
Circuitos().circuito_1([0]) # ENTRADA: 01
# Out:
# None

# %%
Circuitos().circuito_1([1]) # ENTRADA: 10
# Out:
# None

# %%
Circuitos().circuito_1([0, 1]) # ENTRADA: 11
# Out:
# None
